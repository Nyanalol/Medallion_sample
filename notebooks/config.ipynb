# %% [markdown]
# # config
#
# Notebook de configuración compartida. **No ejecutar directamente.**
#
# Se referencia desde los demás notebooks con:
# ```
# %run ./config
# ```
# Esto inyecta todas las variables en el scope del notebook llamante.

# %%
# ─── LAKEHOUSES ───────────────────────────────────────────────────────────────
# Ajusta estos nombres a los nombres exactos de tus lakehouses en Fabric
BRONZE_LAKEHOUSE = "lakehouse_poc"
SILVER_LAKEHOUSE = "silver_lakehouse_poc"
GOLD_LAKEHOUSE   = "gold_lakehouse_poc"

# ─── SCHEMAS ──────────────────────────────────────────────────────────────────
DEFAULT_SCHEMA = "dbo"

# ─── DATA QUALITY ─────────────────────────────────────────────────────────────
# Umbral para detectar valores anómalos en salestrack_sales_final.original_unidades
UNIDADES_ANOMALY_THRESHOLD = 1_000_000
# ──────────────────────────────────────────────────────────────────────────────

print(f"Config cargada → Bronze: {BRONZE_LAKEHOUSE} | Silver: {SILVER_LAKEHOUSE} | Gold: {GOLD_LAKEHOUSE}")
